# %%
# !fast-downward --plan-file sas_plan_puzzle_cheat_ff puzzle_cheat_domain.pddl puzzle_cheat01.pddl --heuristic "h=ff()" --search "eager_greedy([h])"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /opt/miniconda3/envs/aima_plan/bin/python /opt/miniconda3/envs/aima_plan/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py puzzle_cheat_domain.pddl puzzle_cheat01.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.004s wall-clock]
# Preparing model... [0.000s CPU, 0.002s wall-clock]
# Generated 65 rules.
# Computing model... [0.030s CPU, 0.028s wall-clock]
# 1547 relevant atoms
# 1829 auxiliary atoms
# 3376 final queue length
# 5281 total queue pushes
# Completing instantiation... [0.040s CPU, 0.042s wall-clock]
# ...
