# %%
# !fast-downward --plan-file sas_plan_deliveroo delivery_domain.pddl delivery01.pddl --heuristic "h=blind()" --search "astar(h)"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /opt/miniconda3/envs/aima_plan/bin/python /opt/miniconda3/envs/aima_plan/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py delivery_domain.pddl delivery01.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.001s wall-clock]
# Normalizing task... [0.000s CPU, 0.001s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.010s CPU, 0.001s wall-clock]
# Generated 33 rules.
# Computing model... [0.000s CPU, 0.003s wall-clock]
# 147 relevant atoms
# 166 auxiliary atoms
# 313 final queue length
# 367 total queue pushes
# Completing instantiation... [0.000s CPU, 0.002s wall-clock]
# ...
