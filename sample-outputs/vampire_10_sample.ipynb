# %%
# !fast-downward vampire_domain.pddl vampire09.pddl --heuristic "h=blind()" --search "astar(h)"
# Out:
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /opt/miniconda3/envs/aima_plan/bin/python /opt/miniconda3/envs/aima_plan/lib/Fast-Downward-19.06.0/builds/release/bin/translate/translate.py vampire_domain.pddl vampire09.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.010s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 43 rules.
# Computing model... [0.000s CPU, 0.008s wall-clock]
# 125 relevant atoms
# 409 auxiliary atoms
# 534 final queue length
# 3567 total queue pushes
# Completing instantiation... [0.010s CPU, 0.004s wall-clock]
# ...
